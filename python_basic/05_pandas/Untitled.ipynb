# %%
import OpenDartReader

# %%
api_key = 'fd924af55c6de2bb54c3356573b8c2b2f40aa14c'

# %%
dart = OpenDartReader(api_key)

# %%
dart.finstate('삼성전자', 2021)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 1   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 2   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 3   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 4   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 5   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 6   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 7   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 8   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 9   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 10  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# ...

# %%
attaches = dart.attach_file_list('20220308000798')
xls_url = attaches.loc[attaches['type']=='excel','url'].values[0]
dart.retrieve(xls_url, '삼성전자_2021.xls')
# Out:
# '삼성전자_2021.xls'

# %%
import pandas as pd
xl = pd.ExcelFile('삼성전자_2021.xls')
xl.sheet_names
# Out:
# ['기본정보',
#  '연결 재무상태표',
#  '연결 손익계산서',
#  '연결 포괄손익계산서',
#  '연결 자본변동표',
#  '연결 현금흐름표',
#  '재무상태표',
#  '손익계산서',
#  '포괄손익계산서',
#  '자본변동표',
#  '현금흐름표']

# %%
pd.read_excel('삼성전자_2021.xls',sheet_name='연결 손익계산서', skiprows=6)
# Out:
#                                        제 53 기     제 52 기     제 51 기
# 0                          수익(매출액)  279604799  236806988  230400881
# 1                             매출원가  166411342  144488296  147239549
# 2                            매출총이익  113193457   92318692   83161332
# 3                          판매비와관리비   61559601   56324816   55392823
# 4                             영업이익   51633856   35993876   27768509
# 5                             기타수익    2205695    1384068    1778666
# 6                             기타비용    2055971    2488902    1414707
# 7                            지분법이익     729614     506530     412960
# 8                             금융수익    8543187   12267600   10161632
# 9                             금융비용    7704554   11318055    8274871
# 10                 법인세비용차감전순이익(손실)   53351827   36345117   30432189
# 11                           법인세비용   13444377    9937285    8693324
# 12                      계속영업이익(손실)   39907450   26407832   21738865
# ...
